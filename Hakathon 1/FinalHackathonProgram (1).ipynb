# %%
import matplotlib. pyplot as plt
import pandas as pd
print("Welcome to the Superhero Data Analysis Software")
print("-"*127)
link=('Avengers_ Assemble final Dataset.csv')
df=pd.read_csv(link)
def data_types():
    data_types=df.dtypes
    print("Data types of each column")
    print(data_types)
def names():
    avengers_names=df[['name']]
    print("Name of each avenger:")
    print(avengers_names)
def superpower():
    power=str(input("Enter a power/ability to search for: "))
    hero_power=df[df['ability']==power]
    print(f"Heroes with  {power} : ")
    print()
    print(hero_power[['name','ability']])
def experience():
    limit=int(input("Enter the hero experience limit: "))
    with_experience=df[df['age']>limit]
    print(f"Heroes with more experience than {limit} years of experience: ")
    print()
    print(with_experience[['name','ability','age']])
def age_sorter():
    sorted_by_age=df.sort_values(by='age',ascending=True)
    print("All heroes sorted by age: ")
    print()
    print(sorted_by_age[['name','Gender','age']])
def team_sorter():
    team=str(input("Enter name of team: "))
    print(f"All Heroes in team {team}: ")
    print()
    hero_team=df[df['work_affiliation']==team]
    print(hero_team[['name','age','ability']])
def villian_sorter():
    villian=str(input("Enter name of villian: "))
    print(f"All Heroes who have faced {villian} are : ")
    heroes_against=df[df['enemy']==villian]
    print()
    print(heroes_against[['name','ability','work_affiliation']])
def pie_chart_for_powers():
    plt.figure(figsize=(10,10))
    type_counts=df['ability'].value_counts()
    plt.pie(type_counts,labels=type_counts.index,startangle=60,autopct='%1.0f%%')
    plt.title("Distribution of abilities: ")
    plt.show()
def bar_chart_enemies():
    plt.figure(figsize=(12,8))
    enemy_counts=df['enemy'].value_counts()
    enemy_counts.plot(kind='bar',color='lightgreen')
    plt.xlabel("Enemies")
    plt.ylabel("Number of times heroes faced enemies")
    plt.title("Avengers against enemies")
    plt.xticks(rotation=70)
    plt.show()
def pie_chart_affiliation():
    plt.figure(figsize=(10,10))
    type_counts=df['work_affiliation'].value_counts()
    plt.pie(type_counts,labels=type_counts.index,autopct='%1.0f%%',startangle=70)
    plt.title("Distribution of affiliations: ")
    plt.show()
def bar_chart_availability():
    plt.figure(figsize=(12,8))
    enemy_counts=df['availability'].value_counts()
    enemy_counts.plot(kind='bar',color='lightgreen')
    plt.xlabel("Availability")
    plt.ylabel("Number of Heroes available")
    plt.xticks(rotation=0)
    plt.title('Availability of Different Heroes')
    plt.tight_layout()
    plt.show()
print("Choose from the following options: ")
print("1.Print DataFrame")
print("2.Data Detective")
print("3.Superpower Search")
print("4.Hero Experience")
print("5.Age Time Machine")
print("6.Name Explorer")
print("7.Team Detective")
print("8.Enemy Encounter")
print("9.Superpower Pie")
print("10.Team Dynamics Chart")
print("11.Ready for Action")
print("12.Battle Graph")
print("13.Exit")
n=1
while n!=0:
    decision=int(input("Enter The Option Number You Want To Access: "))
    if decision==1:
        print(df)
    elif decision==2:
        data_types()
    elif decision==3:
        superpower()
    elif decision==4:
        experience()
    elif decision==5:
        age_sorter()
    elif decision==6:
        names()
    elif decision==7:
        team_sorter()
    elif decision==8:
        villian_sorter()
    elif decision==9:
        pie_chart_for_powers()
    elif decision==10:
         pie_chart_affiliation()
    elif decision==11:
                bar_chart_availability()
    elif decision==12:
                bar_chart_enemies()
    elif decision==13:
        print("Thank you for using the Superhero Data Analysis Software")
        break
    else:
        print("Sorry,We Do Not Have That Option.")
# Out:
# Welcome to the Superhero Data Analysis Software
# -------------------------------------------------------------------------------------------------------------------------------
# Choose from the following options:
# 1.Print DataFrame
# 2.Data Detective
# 3.Superpower Search
# 4.Hero Experience
# 5.Age Time Machine
# 6.Name Explorer
# 7.Team Detective
# 8.Enemy Encounter
# 9.Superpower Pie
# 10.Team Dynamics Chart
# 11.Ready for Action
# 12.Battle Graph
# 13.Exit
# Enter The Option Number You Want To Access: 12
# Enter The Option Number You Want To Access: 6
# Name of each avenger:
#                          name
# 0                    Iron Man
# 1                        Thor
# 2                        Hulk
# 3             Captain America
# 4                 Black Widow
# 5                     Hawkeye
# 6               Scarlet Witch
# 7               Black Panther
# 8              Doctor Strange
# 9                     Ant-Man
# 10                 Spider-Man
# 11             Captain Marvel
# 12                  Wolverine
# 13                   Deadpool
# 14                     Vision
# 15                     Falcon
# 16                War Machine
# 17                Doctor Doom
# 18                  Black Cat
# 19                Ghost Rider
# 20                Quicksilver
# 21                       Wasp
# 22                     Gamora
# 23             Rocket Raccoon
# 24                      Groot
# 25                  Star-Lord
# 26             Winter Soldier
# 27                  Daredevil
# 28                  Luke Cage
# 29              Jessica Jones
# 30                  Iron Fist
# 31                    Elektra
# 32                   Punisher
# 33                      Shuri
# 34                     Mantis
# 35                   Valkyrie
# 36                       Loki
# 37                       Hela
# 38                  Nick Fury
# 39              Agent Coulson
# 40                 Maria Hill
# 41        Falcon (Sam Wilson)
# 42  White Wolf (Bucky Barnes)
# 43                      Okoye
# 44                     M'Baku
# 45                  Shang-Chi
# Enter The Option Number You Want To Access: 3
# Enter a power/ability to search for: Super strength
# Heroes with  Super strength :
#
#                name         ability
# 2              Hulk  Super strength
# 3   Captain America  Super strength
# 7     Black Panther  Super strength
# 10       Spider-Man  Super strength
# 22           Gamora  Super strength
# 26   Winter Soldier  Super strength
# Enter The Option Number You Want To Access: 9
# Enter The Option Number You Want To Access: 11
